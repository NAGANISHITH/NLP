# %% [markdown]
# <a href="https://colab.research.google.com/github/NAGANISHITH/NLP/blob/main/NLP_LAB_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample dataset
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# (a) Data Preprocessing
def preprocess_data(data):
    # Split English and French sentences
    eng_texts = [pair[0] for pair in data]
    fra_texts = ['<start> ' + pair[1] + ' <end>' for pair in data]

    # Create tokenizers
    eng_tokenizer = Tokenizer()
    fra_tokenizer = Tokenizer()

    # Fit tokenizers
    eng_tokenizer.fit_on_texts(eng_texts)
    fra_tokenizer.fit_on_texts(fra_texts)

    # Convert texts to sequences
    eng_sequences = eng_tokenizer.texts_to_sequences(eng_texts)
    fra_sequences = fra_tokenizer.texts_to_sequences(fra_texts)

    # Find maximum lengths
    max_eng_len = max(len(seq) for seq in eng_sequences)
    max_fra_len = max(len(seq) for seq in fra_sequences)

    # Pad sequences
    eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
    fra_padded = pad_sequences(fra_sequences, maxlen=max_fra_len, padding='post')

    return eng_padded, fra_padded, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len

# Process the data
eng_data, fra_data, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len = preprocess_data(data)

# Get vocabulary sizes
eng_vocab_size = len(eng_tokenizer.word_index) + 1
fra_vocab_size = len(fra_tokenizer.word_index) + 1

# Print shapes for debugging
print("Input shapes:")
print(f"English data shape: {eng_data.shape}")
print(f"French data shape: {fra_data.shape}")

# (b) Build Seq2Seq Model
def build_model(input_vocab, output_vocab, input_length, output_length):
    # Encoder
    encoder_inputs = Input(shape=(input_length,))
    encoder_embedding = Embedding(input_vocab, 50)(encoder_inputs)
    encoder = LSTM(100, return_state=True)
    encoder_outputs, state_h, state_c = encoder(encoder_embedding)
    encoder_states = [state_h, state_c]

    # Decoder
    decoder_inputs = Input(shape=(output_length,))
    decoder_embedding = Embedding(output_vocab, 50)(decoder_inputs)
    decoder_lstm = LSTM(100, return_sequences=True)
    decoder_outputs = decoder_lstm(decoder_embedding, initial_state=encoder_states)
    decoder_dense = Dense(output_vocab, activation='softmax')
    decoder_outputs = decoder_dense(decoder_outputs)

    # Create model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    return model

# (c) Prepare Data for Training
decoder_input_data = fra_data[:, :-1]  # Remove last token
decoder_target_data = fra_data[:, 1:]  # Remove first token

# Print shapes for debugging
print("\nTraining data shapes:")
print(f"Decoder input shape: {decoder_input_data.shape}")
print(f"Decoder target shape: {decoder_target_data.shape}")

# (d) Train the Model
model = build_model(
    eng_vocab_size,
    fra_vocab_size,
    max_eng_len,
    max_fra_len - 1
)

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    [eng_data, decoder_input_data],
    decoder_target_data,
    batch_size=2,
    epochs=100,
    validation_split=0.2
)

# (e) Inference Setup
class Translator:
    def __init__(self, model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len):
        self.model = model
        self.eng_tokenizer = eng_tokenizer
        self.fra_tokenizer = fra_tokenizer
        self.max_eng_len = max_eng_len
        self.max_fra_len = max_fra_len
        self.fra_index_word = {v: k for k, v in fra_tokenizer.word_index.items()}

    def translate(self, text):
        # Tokenize input text
        sequence = self.eng_tokenizer.texts_to_sequences([text])
        padded = pad_sequences(sequence, maxlen=self.max_eng_len, padding='post')

        # Initialize target sequence
        target_seq = np.zeros((1, self.max_fra_len - 1))

        # Generate translation
        prediction = self.model.predict([padded, target_seq])

        # Convert prediction to text
        output_sequence = np.argmax(prediction[0], axis=1)
        translated_text = []

        for idx in output_sequence:
            if idx != 0:
                word = self.fra_index_word.get(idx, '')
                if word and word not in ['<start>', '<end>']:
                    translated_text.append(word)

        return ' '.join(translated_text)

# (f) Translate New Sentences

translator = Translator(model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len)

# Test translations
test_sentences = [
    "hello",
    "thank you",
    "your name",
    "how are you"
]

print("\nTranslations:")
for sentence in test_sentences:
    translation = translator.translate(sentence)
    print(f"English: {sentence}")
    print(f"French: {translation}\n")
# Out:
# Input shapes:
# English data shape: (7, 4)
# French data shape: (7, 5)
#
# Training data shapes:
# Decoder input shape: (7, 4)
# Decoder target shape: (7, 4)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 230ms/step - accuracy: 0.2188 - loss: 2.7689 - val_accuracy: 0.6250 - val_loss: 2.7557
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3219 - loss: 2.7488 - val_accuracy: 0.3750 - val_loss: 2.7428
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3938 - loss: 2.7311 - val_accuracy: 0.2500 - val_loss: 2.7278
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.7163 - val_accuracy: 0.2500 - val_loss: 2.7108
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.6813 - val_accuracy: 0.2500 - val_loss: 2.6821
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.6459 - val_accuracy: 0.2500 - val_loss: 2.6432
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.6135 - val_accuracy: 0.2500 - val_loss: 2.5894
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2500 - loss: 2.5167 - val_accuracy: 0.2500 - val_loss: 2.5036
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.4579 - val_accuracy: 0.2500 - val_loss: 2.3925
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2500 - loss: 2.3445 - val_accuracy: 0.2500 - val_loss: 2.2783
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.2500 - loss: 2.1357 - val_accuracy: 0.2500 - val_loss: 2.2152
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2500 - loss: 2.0737 - val_accuracy: 0.2500 - val_loss: 2.1687
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2500 - loss: 1.9533 - val_accuracy: 0.5000 - val_loss: 2.1203
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.4187 - loss: 1.9947 - val_accuracy: 0.5000 - val_loss: 2.0999
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.3313 - loss: 2.0324 - val_accuracy: 0.5000 - val_loss: 2.1070
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3625 - loss: 1.9108 - val_accuracy: 0.5000 - val_loss: 2.1270
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3625 - loss: 1.8703 - val_accuracy: 0.6250 - val_loss: 2.1580
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3625 - loss: 1.7648 - val_accuracy: 0.5000 - val_loss: 2.2018
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.3406 - loss: 1.8914 - val_accuracy: 0.5000 - val_loss: 2.2649
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4344 - loss: 1.6630 - val_accuracy: 0.5000 - val_loss: 2.3375
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5000 - loss: 1.5944 - val_accuracy: 0.3750 - val_loss: 2.4348
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5719 - loss: 1.6549 - val_accuracy: 0.3750 - val_loss: 2.5299
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6125 - loss: 1.4796 - val_accuracy: 0.3750 - val_loss: 2.6164
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6125 - loss: 1.3902 - val_accuracy: 0.5000 - val_loss: 2.7222
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6125 - loss: 1.3078 - val_accuracy: 0.5000 - val_loss: 2.8528
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5969 - loss: 1.3367 - val_accuracy: 0.3750 - val_loss: 3.0011
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5969 - loss: 1.1907 - val_accuracy: 0.3750 - val_loss: 3.1638
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5813 - loss: 1.1741 - val_accuracy: 0.3750 - val_loss: 3.3244
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5906 - loss: 1.2042 - val_accuracy: 0.3750 - val_loss: 3.4762
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.6687 - loss: 0.9827 - val_accuracy: 0.3750 - val_loss: 3.6253
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7500 - loss: 0.9726 - val_accuracy: 0.3750 - val_loss: 3.7642
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7906 - loss: 0.8043 - val_accuracy: 0.3750 - val_loss: 3.8975
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8469 - loss: 0.7487 - val_accuracy: 0.3750 - val_loss: 4.0299
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9594 - loss: 0.6574 - val_accuracy: 0.3750 - val_loss: 4.1562
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9594 - loss: 0.5238 - val_accuracy: 0.2500 - val_loss: 4.3003
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9594 - loss: 0.5489 - val_accuracy: 0.2500 - val_loss: 4.4402
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.4534 - val_accuracy: 0.3750 - val_loss: 4.4965
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.4246 - val_accuracy: 0.3750 - val_loss: 4.5665
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.3708 - val_accuracy: 0.2500 - val_loss: 4.6409
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.3760 - val_accuracy: 0.2500 - val_loss: 4.6600
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9281 - loss: 0.3515 - val_accuracy: 0.2500 - val_loss: 4.7819
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.3124 - val_accuracy: 0.1250 - val_loss: 4.9401
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.2726 - val_accuracy: 0.3750 - val_loss: 4.8974
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.2586 - val_accuracy: 0.2500 - val_loss: 4.9234
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2233 - val_accuracy: 0.2500 - val_loss: 4.9937
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.2019 - val_accuracy: 0.2500 - val_loss: 5.0888
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.1862 - val_accuracy: 0.1250 - val_loss: 5.1872
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 0.1694 - val_accuracy: 0.1250 - val_loss: 5.2380
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 1.0000 - loss: 0.1494 - val_accuracy: 0.1250 - val_loss: 5.2555
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 1.0000 - loss: 0.1420 - val_accuracy: 0.2500 - val_loss: 5.2598
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.1281 - val_accuracy: 0.2500 - val_loss: 5.2786
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.1279 - val_accuracy: 0.2500 - val_loss: 5.3202
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1236 - val_accuracy: 0.1250 - val_loss: 5.3687
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1052 - val_accuracy: 0.1250 - val_loss: 5.3869
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.1084 - val_accuracy: 0.1250 - val_loss: 5.4051
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1032 - val_accuracy: 0.1250 - val_loss: 5.4316
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0921 - val_accuracy: 0.1250 - val_loss: 5.4296
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0917 - val_accuracy: 0.1250 - val_loss: 5.4166
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0901 - val_accuracy: 0.1250 - val_loss: 5.4413
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0793 - val_accuracy: 0.1250 - val_loss: 5.4758
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0743 - val_accuracy: 0.1250 - val_loss: 5.4980
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0717 - val_accuracy: 0.1250 - val_loss: 5.4855
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0703 - val_accuracy: 0.1250 - val_loss: 5.4739
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0699 - val_accuracy: 0.1250 - val_loss: 5.5049
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0654 - val_accuracy: 0.1250 - val_loss: 5.5465
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0627 - val_accuracy: 0.1250 - val_loss: 5.5472
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0577 - val_accuracy: 0.1250 - val_loss: 5.5390
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0578 - val_accuracy: 0.1250 - val_loss: 5.5579
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0577 - val_accuracy: 0.1250 - val_loss: 5.5947
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.0526 - val_accuracy: 0.1250 - val_loss: 5.6167
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0523 - val_accuracy: 0.1250 - val_loss: 5.6089
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0490 - val_accuracy: 0.1250 - val_loss: 5.6043
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0472 - val_accuracy: 0.1250 - val_loss: 5.6203
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0453 - val_accuracy: 0.1250 - val_loss: 5.6405
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 0.0450 - val_accuracy: 0.1250 - val_loss: 5.6537
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0442 - val_accuracy: 0.1250 - val_loss: 5.6560
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 0.0414 - val_accuracy: 0.1250 - val_loss: 5.6578
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0419 - val_accuracy: 0.1250 - val_loss: 5.6691
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0406 - val_accuracy: 0.1250 - val_loss: 5.6803
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 0.1250 - val_loss: 5.6885
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0376 - val_accuracy: 0.1250 - val_loss: 5.6903
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0363 - val_accuracy: 0.1250 - val_loss: 5.6990
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0340 - val_accuracy: 0.1250 - val_loss: 5.7140
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0339 - val_accuracy: 0.1250 - val_loss: 5.7235
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0342 - val_accuracy: 0.1250 - val_loss: 5.7280
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0333 - val_accuracy: 0.1250 - val_loss: 5.7338
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0292 - val_accuracy: 0.1250 - val_loss: 5.7405
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0305 - val_accuracy: 0.1250 - val_loss: 5.7446
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0304 - val_accuracy: 0.1250 - val_loss: 5.7526
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.1250 - val_loss: 5.7617
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 0.0283 - val_accuracy: 0.1250 - val_loss: 5.7652
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0267 - val_accuracy: 0.1250 - val_loss: 5.7707
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 0.1250 - val_loss: 5.7779
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0257 - val_accuracy: 0.1250 - val_loss: 5.7848
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0251 - val_accuracy: 0.1250 - val_loss: 5.7908
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0241 - val_accuracy: 0.1250 - val_loss: 5.7967
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0250 - val_accuracy: 0.1250 - val_loss: 5.8036
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 1.0000 - loss: 0.0238 - val_accuracy: 0.1250 - val_loss: 5.8101
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.1250 - val_loss: 5.8170
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.0212 - val_accuracy: 0.1250 - val_loss: 5.8232
#
# Translations:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# English: hello
# French: bonjour end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# English: thank you
# French: je end end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# English: your name
# French: je m'appelle end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# English: how are you
# French: comment ça va end
